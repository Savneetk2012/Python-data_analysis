# %%
import pandas as pd
df=pd.read_csv("C:/Users/savneet kuar/Documents/datasets/country_wise_latest.csv")
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
import pandas as pd
df1=pd.read_csv("C:/Users/savneet kuar/Documents/datasets/rectangular_data_dog.csv")
df1
# Out:
#      Name         Breed  Color   Height(cm)  Weight(kg) Date of Birth
# 0    Bella     Labrador  Brown           56          25    2013-07-01
# 1  Charlie       Poodle  Black           43          23    2016-09-16
# 2     Lucy    Chow Chow  Brown           46          22    2014-08-25
# 3   Cooper    Schnauzer   Gray           49          17    2011-01-09
# 4      Max     Labrador  Black           59          29    2017-01-20
# 5   Stella    Chihuahua    Tan           18           2    2015-04-20
# 6   Bernie  St. Bernard  White           77          74    2018-02-27

# %%
df1.groupby("Color")["Weight(kg)"].agg([min,max,sum])
# Out:
#        min  max  sum
# Color
# Black   23   29   52
# Brown   22   25   47
# Gray    17   17   17
# Tan      2    2    2
# White   74   74   74

# %%
df1.groupby(["Color","Breed"])[["Weight(kg)"]].mean()
# Out:
#                    Weight(kg)
# Color Breed
# Black Labrador             29
#       Poodle               23
# Brown Chow Chow            22
#       Labrador             25
# Gray  Schnauzer            17
# Tan   Chihuahua             2
# White St. Bernard          74

# %%
is_young=df1["Date of Birth"]<="2011-01-09"

df1[is_young]
# Out:
#     Name       Breed Color   Height(cm)  Weight(kg) Date of Birth
# 3  Cooper  Schnauzer  Gray           49          17    2011-01-09

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           7 non-null      object
#  1   Breed          7 non-null      object
#  2   Color          7 non-null      object
#  3    Height(cm)    7 non-null      int64
#  4   Weight(kg)     7 non-null      int64
#  5   Date of Birth  7 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 464.0+ bytes

# %%
df1.head()
# Out:
#      Name       Breed  Color   Height(cm)  Weight(kg) Date of Birth
# 0    Bella   Labrador  Brown           56          25    01-07-2013
# 1  Charlie     Poodle  Black           43          23    16-09-2016
# 2     Lucy  Chow Chow  Brown           46          22    25-08-2014
# 3   Cooper  Schnauzer   Gray           49          17    11-12-2011
# 4      Max   Labrador  Black           59          29    20-01-2017

# %%
df1.tail()
# Out:
#     Name         Breed  Color   Height(cm)  Weight(kg) Date of Birth
# 2    Lucy    Chow Chow  Brown           46          22    25-08-2014
# 3  Cooper    Schnauzer   Gray           49          17    11-12-2011
# 4     Max     Labrador  Black           59          29    20-01-2017
# 5  Stella    Chihuahua    Tan           18           2    20-04-2015
# 6  Bernie  St. Bernard  White           77          74    27-02-2018

# %%
#shape is an attribute therefore doesn't have brackets
df1.shape
# Out:
# (7, 6)

# %%
#describe is a method therefore has brackets
df1.describe()
# Out:
#         Height(cm)  Weight(kg)
# count     7.000000    7.000000
# mean     49.714286   27.428571
# std      17.960274   22.292429
# min      18.000000    2.000000
# 25%      44.500000   19.500000
# 50%      49.000000   23.000000
# 75%      57.500000   27.000000
# max      77.000000   74.000000

# %%
cols_to_subset=["Breed","Color"]
df1[cols_to_subset]
# Out:
#          Breed  Color
# 0     Labrador  Brown
# 1       Poodle  Black
# 2    Chow Chow  Brown
# 3    Schnauzer   Gray
# 4     Labrador  Black
# 5    Chihuahua    Tan
# 6  St. Bernard  White

# %%
df1["Weight(kg)"].cumsum()
# Out:
# 0     25
# 1     48
# 2     70
# 3     87
# 4    116
# 5    118
# 6    192
# Name: Weight(kg), dtype: int64

# %%
df1["Weight(kg)"].cumprod()
# Out:
# 0           25
# 1          575
# 2        12650
# 3       215050
# 4      6236450
# 5     12472900
# 6    922994600
# Name: Weight(kg), dtype: int64

# %%
df1["Weight(kg)"].cummin()
# Out:
# 0    25
# 1    23
# 2    22
# 3    17
# 4    17
# 5     2
# 6     2
# Name: Weight(kg), dtype: int64

# %%
df1["Weight(kg)"].cummax()
# Out:
# 0    25
# 1    25
# 2    25
# 3    25
# 4    29
# 5    29
# 6    74
# Name: Weight(kg), dtype: int64

# %%
df1.drop_duplicates(subset="Weight(kg)")
# Out:
#      Name         Breed  Color   Height(cm)  Weight(kg) Date of Birth
# 0    Bella     Labrador  Brown           56          25    01-07-2013
# 1  Charlie       Poodle  Black           43          23    16-09-2016
# 2     Lucy    Chow Chow  Brown           46          22    25-08-2014
# 3   Cooper    Schnauzer   Gray           49          17    09-01-2011
# 4      Max     Labrador  Black           59          29    20-01-2017
# 5   Stella    Chihuahua    Tan           18           2    20-04-2015
# 6   Bernie  St. Bernard  White           77          74    27-02-2018

# %%
df1["Breed"].value_counts()
# Out:
# Labrador       2
# Chihuahua      1
# Schnauzer      1
# Poodle         1
# St. Bernard    1
# Chow Chow      1
# Name: Breed, dtype: int64

# %%
df1["Breed"].value_counts(normalize=True)
# Out:
# Labrador       0.285714
# Chihuahua      0.142857
# Schnauzer      0.142857
# Poodle         0.142857
# St. Bernard    0.142857
# Chow Chow      0.142857
# Name: Breed, dtype: float64

# %%
df1.groupby("Color")["Weight(kg)"].mean()
# Out:
# Color
# Black    26.0
# Brown    23.5
# Gray     17.0
# Tan       2.0
# White    74.0
# Name: Weight(kg), dtype: float64

# %%
df1.groupby("Breed")["Weight(kg)"].mean()
# Out:
# Breed
# Chihuahua       2
# Chow Chow      22
# Labrador       27
# Poodle         23
# Schnauzer      17
# St. Bernard    74
# Name: Weight(kg), dtype: int64
